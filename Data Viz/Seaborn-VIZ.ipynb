# %% [markdown]
# # Descriptive Statistics Review

# %% [markdown]
# ## Context

# %% [markdown]
# ![img](./diamonds.jpg)

# %% [markdown]
# The dataset we will be using is comprised of approximately 54k rows and 11 different columns. As always, a row represents a single observation (in this case a diamond) and each of the columns represent a different feature of a diamond.
#
# The following codebook was provided together with the dataset to clarify what each column represents:

# %% [markdown]
# | Column  | Description  |
# |---|---|
# | Price  | Price in US dollars (326-18,823)  |
# | Carat  | Weight of the diamond (0.2--5.01)  |
# | Cut  | Quality of the cut (Fair, Good, Very Good, Premium, Ideal)  |
# | Color  | Diamond colour, from J (worst) to D (best)  |
# | Clarity  | A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))   |
# | x  | Length in mm (0--10.74)  |
# | y  | Width in mm (0--58.9)  |
# | z  | Depth in mm (0--31.8)  |
# | Depth  | Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)  |
# | Table  | Width of top of diamond relative to widest point (43--95)  |

# %% [markdown]
# ## Libraries
# Pandas and numpy will be needed for the analysis of the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# First import the data from the .csv file provided and assign it to a variable named `diamonds` and drop the column with the index.

# %%
#your code here
diamonds=pd.read_csv(r'C:\Users\lenovo\Desktop\ironhack\Projects\Project4\Cleaned_Diamonds.csv')

# %%
diamonds.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z  clarity_n  color_n
# 0  2.43          1        5
# 1  2.31          2        5
# 2  2.31          4        5
# 3  2.63          3        1
# 4  2.75          1        0

# %%
#your thoughts here

# %% [markdown]
# **Seaborn draft**

# %%
data.describe()
#your code here
# 1_Piechart: diamond prices per bin (6 bins)

#binrange
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53931.000000  53931.000000  53931.000000  53931.000000  53931.000000
# mean   26970.541859      0.797857     61.749389     57.457038   3931.982589
# std    15571.609061      0.473962      1.432475      2.234084   3988.612539
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.500000      0.400000     61.000000     56.000000    949.500000
# 50%    26972.000000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.500000      1.040000     62.500000     59.000000   5324.000000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z     clarity_n       color_n
# count  53931.000000  53931.000000  53931.000000  53931.000000  53931.000000
# mean       5.731964      5.733890      3.539651      3.051139      3.405815
# ...

# %%
plt.style.use("ggplot")

# %%
sns.histplot(data=diamonds,x='price',y='carat',hue='color',legend=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
sns.kdeplot(data=diamonds, x="clarity_n", label='clarity_n')
sns.kdeplot(data=diamonds, x="color_n", label='color_n')

plt.legend()
plt.show()

# %%
sns.scatterplot(data=diamonds,x='carat',y='price',hue='color').set_title('carat vs price')
# Out:
# Text(0.5, 1.0, 'carat vs price')

# %%
fig, ax = plt.subplots(figsize=(12,6), ncols=5)
sns.violinplot(data=diamonds,y="carat",color='purple', ax=ax[0])

sns.violinplot(data=diamonds,y="price",color='red', ax=ax[1])
sns.violinplot(data=diamonds,y="x",color='green', ax=ax[2])
sns.violinplot(data=diamonds,y="y",color='blue', ax=ax[3])
sns.violinplot(data=diamonds,y="z",color='yellow', ax=ax[4])

fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6), ncols=4)

sns.boxplot(data=diamonds, y="carat", ax=ax[0])
sns.boxplot(data=diamonds, y="x", ax=ax[1])
sns.boxplot(data=diamonds, y="y", ax=ax[2])
sns.boxplot(data=diamonds, y="z", ax=ax[3])
# Out:
# <AxesSubplot:ylabel='z'>

# %%
corr = diamonds.corr()
#Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
#x= clarity
#y= price/carat
#s= diamond.count (size of bubbles)
#color = color (color of bubbles)
diamonds['price/carat']=diamonds['price']/diamonds['carat']

# %%
diamonds['size']=diamonds.x+diamonds.y+diamonds.z

# %%
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53926       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53927       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53928       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53929       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53930       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
# ...

# %%
diamonds.drop(columns="Unnamed: 0",inplace=True)

# %%
diamonds = diamonds[diamonds.cut.isin(['Premium', 'Good','Ideal']) & diamonds.color.isin(['D', 'F', 'J'])].sample(n=120, random_state=45)

diamonds.shape
# Out:
# (120, 14)

# %%
fig, ax = plt.subplots(figsize=(15,6), ncols=4)
sns.kdeplot(x=diamonds.price, y=diamonds.carat, cmap="Reds", shade=True, bw_adjust=.5,legend=False, ax=ax[0])
sns.scatterplot(x='carat', y='price', hue='cut', style='cut',data=diamonds, s=120,ax=ax[1])
sns.scatterplot(x='carat', y='price/carat', size='price',data=diamonds,legend=False,ax=ax[2])
sns.scatterplot(x='carat', y='price', size='x',data=diamonds,sizes=(50,150),ax=ax[3])

fig.tight_layout()
plt.show()
